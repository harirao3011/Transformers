# %% [markdown]
# <a href="https://colab.research.google.com/github/harirao3011/Transformers/blob/main/Transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers

# %%
from transformers import pipeline

# %%
analyzer = pipeline('sentiment-analysis')
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# ...

# %%
text_input = input('enter the text:')
# Out:
# enter the text:mobile pressor is not performming

# %%
result = analyzer(text_input)

# %%
result
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9990915060043335}]

# %%
text_input = input('enter the text:')
# Out:
# enter the text:mobile is good but processor is  performming poor

# %%
result = analyzer(text_input)

# %%
result
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9951487183570862}]

# %%
generage = pipeline('text-generation')
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# ...

# %%
statement = input('enter the statement:')
# Out:
# enter the statement:HOD of cse is very worst that

# %%
result = generage(statement, max_length=200)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
result
# Out:
# [{'generated_text': "HOD of cse is very worst that you can look at it with this software which allows you to perform a simple scan when you've seen an image, but once you have done that scan, all the important pieces of information have been erased from the output. Then you can just run the scan and see that everything is intact. You can also run the scan and delete the entire image if there would be too much data. And so you can control the image scan speed for yourself to reduce the amount of data you need to write to the flash drive.\n\nAfter that, everything is set up and set up for your next project. However, if you're making something you want from the first image of the project, and you want to edit the images without seeing them, then you have no hope at all. All your images will now be corrupted unless you upload them to your flash drive. The only way to tell if an image is corrupted is to send a signal to your flash drive"}]

# %%
ss=pipeline('ner')
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496 (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# ...

# %%
text = input('enter a statement:')
# Out:
# enter a statement:vignan foundation in guntur

# %%
result = ss(text)

# %%
result
# Out:
# [{'entity': 'I-ORG',
#   'score': np.float32(0.6515623),
#   'index': 2,
#   'word': '##ign',
#   'start': 1,
#   'end': 4}]

# %%
q_a = pipeline('question-answering')
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu

# %%
result = q_a({
    'question': 'what is the purpose of this paragraph?',
    'context': """
    **The Whispering Woods**
    In the village of Elderglen, the Whispering Woods loomed, filled with ancient secrets and eerie murmurs. Many feared its depths, but Elara, a curious and brave girl, decided to explore. As twilight dimmed, she stepped beneath the towering trees, their leaves rustling soft whispers—stories of the past and warnings of danger.

Following the whispers, Elara reached a grand oak with glowing symbols carved into its bark. At its base pulsed a crystal heart, warm and alive. When she touched it, a gentle spirit named Liora appeared, guardian of the forest’s secrets.

“You’ve heard the call,” Liora said. “Will you protect the woods?”

Elara nodded, feeling strength flow through her veins. From that moment, she became the woods’ guardian, preserving its magic and peace. The villagers noticed the forest’s transformation—the whispers now told tales of hope and harmony, thanks to Elara’s courage.


    """
})
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/question_answering.py:390: FutureWarning: Passing a list of SQuAD examples to the pipeline is deprecated and will be removed in v5. Inputs should be passed using the `question` and `context` keyword arguments instead.
#   warnings.warn(

# %%
result
# Out:
# {'score': 0.4716590642929077,
#  'start': 773,
#  'end': 803,
#  'answer': 'preserving its magic and peace'}

# %%
q_a = pipeline('question-answering')

context = """
Flipkart is an e-commerce company based in India.
The OnePlus 10R is a smartphone available on Flipkart.
It features a MediaTek Dimensity 8100-Max processor,
a 4500mAh battery with 150W SUPERVOOC Endurance Edition charging,
and a 6.7-inch 120Hz AMOLED display.
The phone has a triple rear camera setup with a 50MP primary sensor.
It runs on OxygenOS based on Android.
Different variants with varying RAM and storage options are available on Flipkart.
"""

print("Context about Flipkart and OnePlus 10R is loaded.")
print("Ask me questions about the OnePlus 10R. Type 'quit' to exit.")

while True:
    question = input("Enter your question: ")
    if question.lower() == 'quit':
        break

    result_txt = q_a({
        'question': question,
        'context': context
    })

    print("Answer:", result_txt['answer'])
    print("-" * 20) # Separator for clarity

print("Exiting the question-answering session.")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# Context about Flipkart and OnePlus 10R is loaded.
# Ask me questions about the OnePlus 10R. Type 'quit' to exit.
# Enter your question: what is processor
# Answer: MediaTek Dimensity 8100-Max
# --------------------
# Enter your question: quit
# Exiting the question-answering session.

# %%
summarize = pipeline('summarization')
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Device set to use cpu

# %%
try:
    text = input('Enter the text: ')
    print('You entered:', text)
except KeyboardInterrupt:
    print('\nInput was interrupted by the user.')
# Out:
# Enter the text: **The Whispering Woods**     In the village of Elderglen, the Whispering Woods loomed, filled with ancient secrets and eerie murmurs. Many feared its depths, but Elara, a curious and brave girl, decided to explore. As twilight dimmed, she stepped beneath the towering trees, their leaves rustling soft whispers—stories of the past and warnings of danger.  Following the whispers, Elara reached a grand oak with glowing symbols carved into its bark. At its base pulsed a crystal heart, warm and alive. When she touched it, a gentle spirit named Liora appeared, guardian of the forest’s secrets.  “You’ve heard the call,” Liora said. “Will you protect the woods?”  Elara nodded, feeling strength flow through her veins. From that moment, she became the woods’ guardian, preserving its magic and peace. The villagers noticed the forest’s transformation—the whispers now told tales of hope and harmony, thanks to Elara’s courage.       """
# ...

# %%
result = summarize(text,max_length = 100, min_length = 30, do_sample = False)
print(result[0]['summary_text'])
# Out:
#  The Whispering Woods loomed, filled with ancient secrets and eerie murmurs . Many feared its depths, but Elara, a curious and brave girl, decided to explore it . She reached a grand oak with glowing symbols carved into its bark . At its base pulsed a crystal heart, warm and alive, a gentle spirit named Liora appeared, guardian of the forest’s secrets .
